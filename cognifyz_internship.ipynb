# %% [markdown]
# # **RESTAURANT DATASET ANALYSIS**

# %% [markdown]
# **Extracting data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Dataset .csv")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# # **LEVEL 1 TASK 1 -DATA PREPROCESSING**

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df["Cuisines"].value_counts().head()
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Fast Food                354
# North Indian, Mughlai    334
# Name: count, dtype: int64

# %%
df['Cuisines'].fillna(df['Cuisines'].mode()[0], inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
g=sns.displot(df["Aggregate rating"],kde=True)
g.fig.set_figwidth(9.27)
g.fig.set_figheight(5)

# %%
rough=df[(df["Aggregate rating"]==0)]

# %%
rough.shape
# Out:
# (2148, 21)

# %%
df=df[df['Aggregate rating'] != 0]

# %%
df.shape
# Out:
# (7403, 21)

# %%
df["Aggregate rating"].min()
# Out:
# 1.8

# %%
df["Aggregate rating"].max()
# Out:
# 4.9

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=df["Aggregate rating"],data=df)
plt.title('Class Distribution of Aggregate rating')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()

# %%
sns.kdeplot(df["Aggregate rating"])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Density'>

# %% [markdown]
# # **LEVEL1-TASK2: Descriptive Analysis**

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   7.403000e+03   7403.000000  7403.000000  7403.000000
# mean    7.158676e+06     23.268675    63.462859    26.182970
# std     8.444634e+06     63.426253    44.696549    11.267380
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     1.534450e+04      1.000000    77.082416    28.475505
# 50%     3.120540e+05      1.000000    77.191784    28.570000
# 75%     1.821955e+07      1.000000    77.272293    28.645259
# max     1.849606e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           7403.000000  7403.000000       7403.000000   7403.000000
# mean            1448.415102     1.970147          3.440024    202.185060
# std            18303.524265     0.930611          0.552195    479.195199
# min                0.000000     1.000000          1.800000      4.000000
# ...

# %% [markdown]
# **Distribution of categorical values**

# %%
df["Country Code"].value_counts().head()
# Out:
# Country Code
# 1      6513
# 216     431
# 215      79
# 214      60
# 189      60
# Name: count, dtype: int64

# %%
import plotly.express as px
# Count occurrences of each country code
country_counts = df['Country Code'].value_counts().reset_index()
country_counts.columns = ['Country Code', 'count']


fig = px.pie(country_counts, values='count', names='Country Code', title='Country Code Distribution',width=900, height=600)
fig.update_layout(
    margin=dict(t=40, b=40, l=40, r=40))
fig.update_traces(marker=dict(line=dict(width=2)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
color_counts = df['Rating color'].value_counts().reset_index()
color_counts.columns = ['Rating color', 'count']
fig = px.pie(color_counts, values='count', names='Rating color', title='Rating color Distribution',width=900, height=600)
fig.update_layout(
    margin=dict(t=40, b=40, l=40, r=40),# Reduce margins
    title_x=0.5)# Center the title
fig.update_traces(marker=dict(line=dict(width=2)),
                  textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["Restaurant ID"].value_counts().head()
# Out:
# Restaurant ID
# 6317637     1
# 18378050    1
# 313146      1
# 18386078    1
# 18363074    1
# Name: count, dtype: int64

# %%
df["City"].value_counts().head(1)
# Out:
# City
# New Delhi    4048
# Name: count, dtype: int64

# %%
df["Cuisines"].value_counts().head(1)
# Out:
# Cuisines
# North Indian    501
# Name: count, dtype: int64

# %%
df.groupby("Cuisines")["Restaurant ID"].count().sort_values(ascending=False).head()
# Out:
# Cuisines
# North Indian             501
# North Indian, Chinese    397
# North Indian, Mughlai    294
# Cafe                     252
# Fast Food                228
# Name: Restaurant ID, dtype: int64

# %%
cuisines_counts = df['Cuisines'].value_counts().reset_index()
cuisines_counts.columns = ['Cuisines', 'count']
fig = px.pie(cuisines_counts, values='count', names='Cuisines', title='Number of Hotels by Cuisines',width=900, height=600)
fig.update_layout(
    margin=dict(t=40, b=40, l=40, r=40),# Reduce margins
    title_x=0.5)# Center the title
fig.update_traces(marker=dict(line=dict(width=2)),
                  textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# OBSERVATION:
# *  Top cuisines with the highest number of restaurants is North Indian.
#
# *  Top cities with the highest number of restaurants is New Delhi.

# %% [markdown]
# # **LEVEL 1 TASK 3: Geospatial Analysis**

# %%
location=df.groupby(['Latitude','Longitude'],as_index=False).size()

# %%
import folium

# %%
basemap=folium.Map(Location=None)

# %%
from folium.plugins import HeatMap

# %%
HeatMap(location).add_to(basemap)

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **No. of Restaurants by city**

# %%
city_counts = df['City'].value_counts().reset_index()
city_counts.columns = ['City', 'count']
fig = px.pie(city_counts, values='count', names='City', title='No of Restaurant by City',width=900, height=600)
fig.update_layout(
    margin=dict(t=40, b=40, l=40, r=40),# Reduce margins
    title_x=0.5)# Center the title
fig.update_traces(marker=dict(line=dict(width=2)),
                  textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **correlation
# between the restaurant's location and its
# rating.**

# %%
city_ratings = df.groupby('City')['Aggregate rating'].mean().reset_index()

# %%
city_ratings.head()
# Out:
#         City  Aggregate rating
# 0  Abu Dhabi          4.300000
# 1       Agra          3.965000
# 2  Ahmedabad          4.161905
# 3     Albany          3.555000
# 4  Allahabad          3.395000

# %%
plt.figure(figsize=(30, 6))
plt.scatter(x=city_ratings['City'], y=city_ratings['Aggregate rating'])
plt.title('Average Restaurant Rating by City')
plt.xlabel('City')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %%
from scipy.stats import f_oneway
groups = df.groupby('City')['Aggregate rating'].apply(list)
f_stat, p_value = f_oneway(*groups)
alpha = 0.05 # Define the significance level
print(f"F-statistic: {f_stat}, p-value: {p_value}")
if p_value < alpha:
    print("correlated")
else:
    print("not correlated")
# Out:
# F-statistic: 31.644631455864, p-value: 0.0
# correlated

# %% [markdown]
# # LEVEL 3 TASK 1: Predictive Modeling

# %%
df["Cuisines"].nunique()
# Out:
# 1715

# %%
df1=df.copy()

# %% [markdown]
# Encoding:

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df1["City"]=labelencoder.fit_transform(df1["City"])
df1['Cuisines']=labelencoder.fit_transform(df1["Cuisines"])
df1['Has Table booking']=labelencoder.fit_transform(df1["Has Table booking"])
df1['Has Online delivery']=labelencoder.fit_transform(df1["Has Online delivery"])
df1['Is delivering now']=labelencoder.fit_transform(df1["Is delivering now"])
df1['Switch to order menu']=labelencoder.fit_transform(df1["Switch to order menu"])
df1['Rating color']=labelencoder.fit_transform(df1["Rating color"])
df1['Rating text']=labelencoder.fit_transform(df1["Rating text"])

# %%
df1.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code  City  \
# 0        6317637  Le Petit Souffle           162    73
# 1        6304287  Izakaya Kikufuji           162    73
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#    Cuisines  ...          Currency Has Table booking  Has Online delivery  \
# 0       870  ...  Botswana Pula(P)                 1                    0
# 1      1053  ...  Botswana Pula(P)                 1                    0
#
# ...

# %% [markdown]
# Outlier Detection and Handling - Target variable

# %%
sns.boxplot(df1["Aggregate rating"])
# Out:
# <Axes: ylabel='Aggregate rating'>

# %%
rate=df1["Aggregate rating"]
q1=rate.quantile(0.25)
q3=rate.quantile(0.75)
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr

# %%
df1["Aggregate rating"][df1["Aggregate rating"]<lower]=lower
# Out:
# <ipython-input-47-a5850e73330a>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.boxplot(df1["Aggregate rating"])
# Out:
# <Axes: ylabel='Aggregate rating'>

# %% [markdown]
# Train Test Split:

# %%
df1.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code  City  \
# 0        6317637        Le Petit Souffle           162    73
# 1        6304287        Izakaya Kikufuji           162    73
# 2        6300002  Heat - Edsa Shangri-La           162    75
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
#
# ...

# %%
df1.drop(["Restaurant Name","Address","Locality","Locality Verbose","Longitude","Latitude"],axis=1,inplace=True)

# %%
df1.head(1)
# Out:
#    Restaurant ID  Country Code  City  Cuisines  Average Cost for two  \
# 0        6317637           162    73       870                  1100
#
#            Currency  Has Table booking  Has Online delivery  \
# 0  Botswana Pula(P)                  1                    0
#
#    Is delivering now  Switch to order menu  Price range  Aggregate rating  \
# 0                  0                     0            3               4.8
#
#    Rating color  Rating text  Votes
# 0             0            1    314

# %%
x=df1[['Restaurant ID','Country Code', 'City','Cuisines',
       'Average Cost for two', 'Has Table booking',
       'Has Online delivery', 'Is delivering now',
       'Price range', 'Rating color', 'Rating text',
       'Votes']]
y=df1['Aggregate rating']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# Feature Scaling:

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit_transform(df1[["Votes"]])
# Out:
# array([[0.02836231],
#        [0.0537054 ],
#        [0.02433669],
#        ...,
#        [0.06010979],
#        [0.0820677 ],
#        [0.0537054 ]])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit_transform(df1[["Price range"]])
# Out:
# array([[0.66666667],
#        [0.66666667],
#        [1.        ],
#        ...,
#        [1.        ],
#        [1.        ],
#        [0.33333333]])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit_transform(df1[["Average Cost for two"]])
# Out:
# array([[1.375e-03],
#        [1.500e-03],
#        [5.000e-03],
#        ...,
#        [2.125e-04],
#        [1.500e-04],
#        [6.875e-05]])

# %% [markdown]
# Feature Selection:

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression
bestfeatures=SelectKBest(mutual_info_regression,k=10)
bestfeatures.fit(x_train,y_train)
x_train_selected=x_train[x_train.columns[bestfeatures.get_support()]]

# %%
x_train_selected.columns
# Out:
# Index(['Restaurant ID', 'Country Code', 'City', 'Cuisines',
#        'Average Cost for two', 'Has Online delivery', 'Price range',
#        'Rating color', 'Rating text', 'Votes'],
#       dtype='object')

# %%
x_test_selected=x_test[x_test.columns[bestfeatures.get_support()]]

# %%
x_train_selected.shape
# Out:
# (5922, 10)

# %% [markdown]
# 1. Linear regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train_selected,y_train)
y_pred=lr.predict(x_test_selected)

# %% [markdown]
# Evaluation Metrics

# %%
#R-Squared:
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.5679342614982406

# %%
#MAE and MSE
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
print("mean absolute error:",mae)
print("mean squared error:",mse)
# Out:
# mean absolute error: 0.2574554481736872
# mean squared error: 0.13774113778143363

# %%
#RMSE
from math import sqrt
rmse=sqrt(mse)
print("root mean squared error:",rmse)
# Out:
# root mean squared error: 0.3711349320414795

# %% [markdown]
# 2. Random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=200,max_depth=5,min_samples_leaf=100,n_jobs=4,random_state=0)
rfr.fit(x_train_selected,y_train)
y_pred=rfr.predict(x_test_selected)

# %% [markdown]
# Evaluation Metrics

# %%
#R-Squared:
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8388072229013785

# %%
#MAE and MSE
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
print("mean absolute error:",mae)
print("mean squared error:",mse)
# Out:
# mean absolute error: 0.17073386922393355
# mean squared error: 0.05138772770251194

# %%
#RMSE
from math import sqrt
rmse=sqrt(mse)
print("root mean squared error:",rmse)
# Out:
# root mean squared error: 0.22668861396751258

# %% [markdown]
# 3. Decision tree regressor

# %%
from sklearn import tree
dt=tree.DecisionTreeRegressor(random_state = 0)
dt.fit(x_train_selected,y_train)
y_pred=dt.predict(x_test_selected)

# %% [markdown]
# Evaluation Metrics

# %%
#R-Squared:
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.782288198775956

# %%
#MAE and MSE
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
print("mean absolute error:",mae)
print("mean squared error:",mse)
# Out:
# mean absolute error: 0.18440243079000673
# mean squared error: 0.06940580688723835

# %%
#RMSE
from math import sqrt
rmse=sqrt(mse)
print("root mean squared error:",rmse)
# Out:
# root mean squared error: 0.26344981853711413

# %%
df1.head(1)
# Out:
#    Restaurant ID  Country Code  City  Cuisines  Average Cost for two  \
# 0        6317637           162    73       870                  1100
#
#            Currency  Has Table booking  Has Online delivery  \
# 0  Botswana Pula(P)                  1                    0
#
#    Is delivering now  Switch to order menu  Price range  Aggregate rating  \
# 0                  0                     0            3               4.8
#
#    Rating color  Rating text  Votes
# 0             0            1    314

# %% [markdown]
# PREDICTION

# %%
inputs=[]
for i in x_train_selected.columns:
  i=float(input(f"enter {i}:"))
  inputs.append(i)
# Out:
# enter Restaurant ID:6317637
# enter Country Code:162
# enter City:73
# enter Cuisines:870
# enter Average Cost for two:1000
# enter Has Online delivery:1
# enter Price range:3
# enter Rating color:4
# enter Rating text:4
# enter Votes:200

# %%
array=np.array(inputs)
array=array.reshape(1,-1)
result=rfr.predict(array)
print("Aggregate rating is",result[0])
# Out:
# Aggregate rating is 3.750909100621429
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning:
#
# X does not have valid feature names, but RandomForestRegressor was fitted with feature names

# %% [markdown]
# # LEVEL 3 TASK 2: Customer Preference Analysis

# %%
from scipy.stats import f_oneway
groups = df.groupby('Cuisines')['Aggregate rating'].apply(list)
f_stat, p_value = f_oneway(*groups)
alpha = 0.05 # Define the significance level
print(f"F-statistic: {f_stat}, p-value: {p_value}")
if p_value < alpha:
    print("correlated")
else:
    print("not correlated")
# Out:
# F-statistic: 3.547744381650563, p-value: 9.377603013246181e-277
# correlated

# %%
cuisine_votes = df.groupby('Cuisines')['Votes'].sum().reset_index()

# %%
cuisine_votes=cuisine_votes.sort_values(by=['Votes'],ascending=False).head(10)

# %%
cuisine_votes.head(2)
# Out:
#                    Cuisines  Votes
# 1437  North Indian, Mughlai  53703
# 1238           North Indian  48620

# %%
plt.figure(figsize=(10,4))
plt.barh(cuisine_votes.Cuisines,cuisine_votes.Votes,color="#78d3b5")
plt.title('Top 10 cuisines among customers based on the number of votes')
plt.ylabel('Cuisines')
plt.xlabel('votes')
#plt.xticks(rotation=75)
plt.show()

# %%
cuisine_rate=df.groupby('Cuisines')['Aggregate rating'].mean().reset_index()

# %%
cuisine_rate= cuisine_rate.sort_values(by=['Aggregate rating'],ascending=False).head(10)

# %%
plt.figure(figsize=(10,4))
plt.barh(cuisine_rate["Cuisines"],cuisine_rate["Aggregate rating"],color="#ffb3ff")
plt.title('Top 10 cuisines among customers based on rating')
plt.ylabel('Cuisines')
plt.xlabel('Aggregate rating')
plt.show()

# %% [markdown]
# # LEVEL 3 TASK 3:Data Visualization

# %%
plt.figure(figsize=(12, 6))
plt.hist(df['Aggregate rating'], bins=10, color='#e0b3ff', edgecolor='black')
plt.title('Distribution of Aggregate Ratings')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.countplot(x=df["Aggregate rating"],data=df,palette='Set2')
plt.title('Class Distribution of Aggregate rating')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()
# Out:
# <ipython-input-123-5b8caa11e2be>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
sns.kdeplot(df["Aggregate rating"])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Density'>

# %%
cuisine_rate = df.groupby('Cuisines')['Aggregate rating'].mean().reset_index()

# %%
cuisine_rate=cuisine_rate.head(100)

# %%
plt.figure(figsize=(30,6))
plt.scatter(x=cuisine_rate['Cuisines'],y=cuisine_rate['Aggregate rating'])
plt.title('Average Restaurant Rating by cuisines')
plt.xlabel('Cuisines')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %%
df2=df1[["Average Cost for two","Has Table booking","Has Online delivery","Price range","Aggregate rating"]]

# %%
sns.pairplot(df2, hue ='Aggregate rating',palette='Set1')
plt.show()

# %%
df3=df1[["Rating color","Rating text","Votes","Aggregate rating"]]

# %%
sns.pairplot(df3, hue ='Aggregate rating',palette='Set1')
plt.show()
